# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy 
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('student-mat.csv')

# %%
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_41488\2718381788.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = data.corr()

# %%
pd.plotting.scatter_matrix(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 pd.plotting.scatter_matrix(df)
# ----> 2 scatter_matrix.show()
#
# NameError: name 'scatter_matrix' is not defined
